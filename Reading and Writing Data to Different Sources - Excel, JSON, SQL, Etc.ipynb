# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df= pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head(50)
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# 6           I am not primarily a developer, but I write co...      Yes
# 7                              I am a developer by profession       No
# 8                                 I code primarily as a hobby      Yes
# 9                              I am a developer by profession      Yes
# 10                             I am a developer by profession      Yes
# 11                                I code primarily as a hobby      Yes
# 12                     I am a student who is learning to code       No
# ...

# %%
df.shape
# Out:
# (88883, 84)

# %%
schema_df
# Out:
#                                                              QuestionText
# Column
# Respondent              Randomized respondent ID number (not in order ...
# MainBranch              Which of the following options best describes ...
# Hobbyist                                          Do you code as a hobby?
# OpenSourcer                   How often do you contribute to open source?
# OpenSource              How do you feel about the quality of open sour...
# Employment              Which of the following best describes your cur...
# Country                         In which country do you currently reside?
# Student                 Are you currently enrolled in a formal, degree...
# EdLevel                 Which of the following best describes the high...
# UndergradMajor          What was your main or most important field of ...
# EduOther                Which of the following types of non-degree edu...
# OrgSize                 Approximately how many people are employed by ...
# ...

# %%
#Suppose we work on our part of our data or the whole of it, and we want to save this work or send it as a csv file to another computer
#We could do this by using the .to_csv('file path') method
#Example suppose we want to store the data of every respondants from india

# %%
filt= df['Country']== 'India'
india_df= df.loc[filt]
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
#Now storing this data into a csv file
india_df.to_csv('data/modified.csv')

# %%
#Now storing this data into a tsv file
india_df.to_csv('data/modified.tsv', sep='\t')

# %%
#Now storing this data into an excel file
india_df.to_excel('data/modified.xlsx')

# %%
#We could also read in the excel file we just created as a dataframe we could work with and specifying the column we want to use as our index
test= pd.read_excel('data/modified.xlsx', index_col= 'Respondent')

# %%
test.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
#Now writing(storing) the india_df data into a json format
india_df.to_json('data/modified.json')

# %%
#We could also specify what format we want the texts in our json file to be displayed by using the orient agrument
india_df.to_json('data/modified.json', orient='records', lines=True)
#Note by default the texts in the json file is of dictionary type

# %%
#We could also read in the json file we just created as a dataframe we could work with and specifying the column we want to use as our index
test2= pd.read_json('data/modified.json', orient='records', lines= True)

# %%
test2
# Out:
#                                   MainBranch Hobbyist  \
# 0                I code primarily as a hobby      Yes
# 1             I am a developer by profession      Yes
# 2     I am a student who is learning to code      Yes
# 3             I am a developer by profession      Yes
# 4             I am a developer by profession      Yes
# ...                                      ...      ...
# 9056                                    None      Yes
# 9057                                    None      Yes
# 9058                                    None      Yes
# 9059                                    None      Yes
# 9060                                    None      Yes
#
#                                             OpenSourcer  \
# 0                               Less than once per year
# 1                            Once a month or more often
# 2                                                 Never
# 3                            Once a month or more often
# ...

# %%
#How to read and write data into a SQL database format
#To do this we need to connect to our SQL database we would need to install SQLAlchemy, which is a popular orm(object relational mapper) for python, that allows us to interact and work with databases.

# %% [markdown]
# ## Working with sql database using MySql workbench

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine('mysql+pymysql://root:Andy2468#@localhost:3306/stud')

# %%
df2= pd.read_sql_table('customers', engine)

# %%
df2
# Out:
#    customer_Id    name phone_number
# 0            1  Donald   7326784567
# 1            2    Bill   6573489999
# 2            3    Modi   4567895646

# %% [raw]
# #Signature:
# pd.read_sql_table(
#     table_name: 'str',
#     con,
#     schema: 'str | None' = None,
#     index_col: 'str | list[str] | None' = None,
#     coerce_float: 'bool' = True,
#     parse_dates: 'list[str] | dict[str, str] | None' = None,
#     columns: 'list[str] | None' = None,
#     chunksize: 'int | None' = None,
# ) -> 'DataFrame | Iterator[DataFrame]'
# Docstring:
# Read SQL database table into a DataFrame.
#
# Given a table name and a SQLAlchemy connectable, returns a DataFrame.
# This function does not support DBAPI connections.
#
# Parameters
# ----------
# table_name : str
#     Name of SQL table in database.
# con : SQLAlchemy connectable or str
#     A database URI could be provided as str.
#     SQLite DBAPI connection mode not supported.
# schema : str, default None
#     Name of SQL schema in database to query (if database flavor
#     supports this). Uses default schema if None (default).
# index_col : str or list of str, optional, default: None
#     Column(s) to set as index(MultiIndex).
# coerce_float : bool, default True
#     Attempts to convert values of non-string, non-numeric objects (like
#     decimal.Decimal) to floating point. Can result in loss of Precision.
# parse_dates : list or dict, default None
#     - List of column names to parse as dates.
#     - Dict of ``{column_name: format string}`` where format string is
#       strftime compatible in case of parsing string times or is one of
#       (D, s, ns, ms, us) in case of parsing integer timestamps.
#     - Dict of ``{column_name: arg dict}``, where the arg dict corresponds
#       to the keyword arguments of :func:`pandas.to_datetime`
#       Especially useful with databases without native Datetime support,
#       such as SQLite.
# columns : list, default None
#     List of column names to select from SQL table.
# chunksize : int, default None
#     If specified, returns an iterator where `chunksize` is the number of
#     rows to include in each chunk.
#
# Returns
# -------
# DataFrame or Iterator[DataFrame]
#     A SQL table is returned as two-dimensional data structure with labeled
#     axes.
#
# See Also
# --------
# read_sql_query : Read SQL query into a DataFrame.
# read_sql : Read SQL query or database table into a DataFrame.
#
# Notes
# -----
# Any datetime values with time zone information will be converted to UTC.
#
# Examples
# --------
# >>> pd.read_sql_table('table_name', 'postgres:///db_name')  # doctest:+SKIP
# File:      c:\users\user\anaconda3\lib\site-packages\pandas\io\sql.py
# Type:      function

# %% [raw]
# namestr
# Name of SQL table.
#
# consqlalchemy.engine.(Engine or Connection) or sqlite3.Connection
# Using SQLAlchemy makes it possible to use any DB supported by that library. Legacy support is provided for sqlite3.Connection objects. The user is responsible for engine disposal and connection closure for the SQLAlchemy connectable. See here. If passing a sqlalchemy.engine.Connection which is already in a transaction, the transaction will not be committed. If passing a sqlite3.Connection, it will not be possible to roll back the record insertion.
#
# schemastr, optional
# Specify the schema (if database flavor supports this). If None, use default schema.
#
# if_exists{‘fail’, ‘replace’, ‘append’}, default ‘fail’
# How to behave if the table already exists.
#
# fail: Raise a ValueError.
#
# replace: Drop the table before inserting new values.
#
# append: Insert new values to the existing table.
#
# indexbool, default True
# Write DataFrame index as a column. Uses index_label as the column name in the table. Creates a table index for this column.
#
# index_labelstr or sequence, default None
# Column label for index column(s). If None is given (default) and index is True, then the index names are used. A sequence should be given if the DataFrame uses MultiIndex.
#
# chunksizeint, optional
# Specify the number of rows in each batch to be written at a time. By default, all rows will be written at once.
#
# dtypedict or scalar, optional
# Specifying the datatype for columns. If a dictionary is used, the keys should be the column names and the values should be the SQLAlchemy types or strings for the sqlite3 legacy mode. If a scalar is provided, it will be applied to all columns.
#
# method{None, ‘multi’, callable}, optional
# Controls the SQL insertion clause used:
#
# None : Uses standard SQL INSERT clause (one per row).
#
# ‘multi’: Pass multiple values in a single INSERT clause.
#
# callable with signature (pd_table, conn, keys, data_iter).
#
# Details and a sample callable implementation can be found in the section insert method.
#
# Returns:
# None or int
# Number of rows affected by to_sql. None is returned if the callable passed into method does not return an integer number of rows.
#
# The number of returned rows affected is the sum of the rowcount attribute of sqlite3.Cursor or SQLAlchemy connectable which may not reflect the exact number of written rows as stipulated in the sqlite3 or SQLAlchemy.

# %%
df3= pd.read_sql_table('customers', engine, columns=['name']) #To get the a particular column in the dataframe.

# %%
df3
# Out:
#      name
# 0  Donald
# 1    Bill
# 2    Modi

# %%
query='''
        SELECT name FROM customers WHERE customer_Id= 2 OR customer_Id= 1
        '''
df3= pd.read_sql_query(query, engine)
df3
# Out:
#    name
# 0  Bill
# 1  Modi

# %%
df2
# Out:
#    customer_Id    name phone_number
# 0            0  Donald   7326784567
# 1            1    Bill   6573489999
# 2            2    Modi   4567895646

# %%
query='''
        SELECT customers.name, customers.phone_number, orders.name, orders.amount
        FROM customers INNER JOIN orders
        ON customers.customer_Id= orders.order_Id
        '''
df2= pd.read_sql_query(query, engine)
df2
# Out:
#      name phone_number          name  amount
# 0  Donald   7326784567  Google Pixel   950.0
# 1    Bill   6573489999      Yoga Mat    20.0
# 2    Modi   4567895646  Fossil Watch   120.0

# %%
Customers= {
        'Customer Name': ['Rafael Nadal', 'Maria sharapova', 'Vladimir Putin',
                         'Kim un Jong', 'Jeff Bezos', 'Rahul Gandhi'],
        'Customer Phone': ['456789647', '43789499040', '45372889291', '1234356990',
                           '9376499573', '443883722']
}

# %%
df5= pd.DataFrame(Customers)

# %%
df5
# Out:
#      Customer Name Customer Phone
# 0     Rafael Nadal      456789647
# 1  Maria sharapova    43789499040
# 2   Vladimir Putin    45372889291
# 3      Kim un Jong     1234356990
# 4       Jeff Bezos     9376499573
# 5     Rahul Gandhi      443883722

# %%
df5.to_excel('data/customers.xlsx')

# %%
df6= pd.read_excel('data/customers.xlsx')

# %%
df6
# Out:
#    Unnamed: 0    Customer Name  Customer Phone
# 0           0     Rafael Nadal       456789647
# 1           1  Maria sharapova     43789499040
# 2           2   Vladimir Putin     45372889291
# 3           3      Kim un Jong      1234356990
# 4           4       Jeff Bezos      9376499573
# 5           5     Rahul Gandhi       443883722

# %%
df6.drop(columns= ['Unnamed: 0'], inplace=True)
#df6.rename(columns={'Unnamed: 0': 'customer_Id'}, inplace= True)

# %%
df6
# Out:
#      Customer Name  Customer Phone
# 0     Rafael Nadal       456789647
# 1  Maria sharapova     43789499040
# 2   Vladimir Putin     45372889291
# 3      Kim un Jong      1234356990
# 4       Jeff Bezos      9376499573
# 5     Rahul Gandhi       443883722

# %%
#We could remname the columns in our customer table.
df5.rename(columns= {'Customer Name' : 'name', 'Customer Phone': 'phone_number'}, inplace= True)

# %%
df5
# Out:
#               name phone_number
# 0     Rafael Nadal    456789647
# 1  Maria sharapova  43789499040
# 2   Vladimir Putin  45372889291
# 3      Kim un Jong   1234356990
# 4       Jeff Bezos   9376499573
# 5     Rahul Gandhi    443883722

# %%
#Appending the above customer table to our existing customer table in MySQL workbench
df5.to_sql(name= 'customers', con= engine, index= False, if_exists= 'append')
# Out:
# 6

# %%
india_df
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
# ...                                            ...      ...
# 77339                                          NaN      Yes
# 79795                                          NaN      Yes
# 83862                                          NaN      Yes
# 84299                                          NaN      Yes
# 86012                                          NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 8                                     Less than once per year
# 10                                 Once a month or more often
# ...

# %%
india_df.to_sql('python_df', con= engine, if_exists= 'replace' )
# Out:
# 9061

# %% [markdown]
# ## Working with sql database using PostgreSql database

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine('postgresql://postgres:Andy2468#@localhost:5432/sample_db')

# %%
#india_df.to_sql('sample_table', engine)
india_df.to_sql('sample_table', engine, if_exists= 'replace') #The if_exists argument helps to replace the table we created in the postgresql if we've already created it.
# Out:
# 61

# %%
#To read data or tables from a Sql database sysetem, in this case postgreSql.
sql_df= pd.read_sql('sample_table', engine, index_col= 'Respondent')

# %%
sql_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
#In the cases we would want to run a particular Sql query from the relational database system
sql_df= pd.read_sql('SELECT * FROM sample_table', engine, index_col= 'Respondent') #Returns the same result since it is selecting all fro the table

# %%
sql_df.head()
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 8                      I code primarily as a hobby      Yes
# 10                  I am a developer by profession      Yes
# 15          I am a student who is learning to code      Yes
# 50                  I am a developer by profession      Yes
# 65                  I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 8              Less than once per year
# 10          Once a month or more often
# 15                               Never
# 50          Once a month or more often
# 65                               Never
#
#                                                    OpenSource  \
# Respondent
# 8           OSS is, on average, of HIGHER quality than pro...
# 10          OSS is, on average, of HIGHER quality than pro...
# 15          OSS is, on average, of HIGHER quality than pro...
# 50          OSS is, on average, of LOWER quality than prop...
# ...

# %%
sql_df= pd.read_sql('SELECT YearsCode FROM sample', engine, index_col= 'Respondent')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# File ~\anaconda3\lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     151 query = self.mogrify(query, args)
# ...
